# %% [markdown]
# <img src="http://cfs22.simplicdn.net/ice9/new_logo.svgz "/>
#
# # Assignment 01: Scrape the Simplilearn Website Homepage
#
# *The comments/sections provided are your cues to perform the assignment. You don't need to limit yourself to the number of rows/cells provided. You can add additional rows in each section to add more lines of code.*
#
# *If at any point in time you need help on solving this assignment, view our demo video to understand the different steps of the code.*
#
# **Happy coding!**
#
# * * *

# %% [markdown]
# #### 1: View and print the Simplilearn web page content in a good format

# %%
#Import the required libraries
from bs4 import BeautifulSoup
import requests
from urllib.request import urlopen

# %%
#Provide the url for web scraping
url=' http://www.simplilearn.com/resources'

# %%
#Scrape the webpage content
webpage= urlopen(url)
#Create a soup object to parse the webpage using html parser
sl_soup= BeautifulSoup(webpage,'html.parser')
webpage.close()

# %%
#View the content of the soup object
sl_soup.contents
# Out:
# ['html',
#  <html dir="ltr" lang="en-US" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <title>Resources | Free Resources to shape your Career - Simplilearn</title>
#  <link href="https://ssl.google-analytics.com/" rel="dns-prefetch"/>
#  <link href="https://stats.g.doubleclick.net/" rel="dns-prefetch">
#  <link href="https://www.google.com/" rel="dns-prefetch"/>
#  <link href="https://cdn.cookielaw.org/" rel="dns-prefetch"/>
#  <link href="https://js-agent.newrelic.com" rel="preconnect"/>
#  <script type="text/javascript">
# ...

# %%
#use the prettify() method to view a well formatted output (with html tags)
print(sl_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US" xmlns="https://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Resources | Free Resources to shape your Career - Simplilearn
#   </title>
#   <link href="https://ssl.google-analytics.com/" rel="dns-prefetch"/>
#   <link href="https://stats.g.doubleclick.net/" rel="dns-prefetch">
#    <link href="https://www.google.com/" rel="dns-prefetch"/>
#    <link href="https://cdn.cookielaw.org/" rel="dns-prefetch"/>
#    <link href="https://js-agent.newrelic.com" rel="preconnect"/>
#    <script type="text/javascript">
# ...

# %% [markdown]
# #### 2: View the head and title of the webpage

# %%
#View the head of the soup object
print(sl_soup.head)
# Out:
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Resources | Free Resources to shape your Career - Simplilearn</title>
# <link href="https://ssl.google-analytics.com/" rel="dns-prefetch"/>
# <link href="https://stats.g.doubleclick.net/" rel="dns-prefetch">
# <link href="https://www.google.com/" rel="dns-prefetch"/>
# <link href="https://cdn.cookielaw.org/" rel="dns-prefetch"/>
# <link href="https://js-agent.newrelic.com" rel="preconnect"/>
# <script type="text/javascript">
# ...

# %%
#View the title of the webpage
print(sl_soup.title)
# Out:
# <title>Resources | Free Resources to shape your Career - Simplilearn</title>

# %% [markdown]
# #### 3: Print all the href links present in the Simplilearn webpage

# %%
#Find all the links present in the webpage
for href in sl_soup.find_all('a', href=True):
    print(href['href'])
# Out:
# https://www.simplilearn.com
#
# https://www.simplilearn.com
# https://www.simplilearn.com/post-graduate-program-in-data-analytics-webinar?source=frs_home_carousal
# https://www.simplilearn.com/full-stack-java-developer-program-webinar?source=frs_home_carousal
# https://www.simplilearn.com/achieve-your-goals-through-time-management-webinar?source=frs_home_carousal
# https://www.simplilearn.com/skills-for-digital-marketing-career-webinar?source=frs_home_carousal
# #data-science-and-business-analytics
# #ai-and-machine-learning
# #project-management
# #cyber-security
# #cloud-computing
# #devops
# #business-and-leadership
# #quality-management
# #software-development
# #agile-and-scrum
# #it-service-and-architecture
# #digital-marketing
# #big-data
# #career-fast-track
# #enterprise
# #other-segments
# https://www.simplilearn.com/resources/data-science-business-analytics?source=frs_home
# https://www.simplilearn.com/data-structure-interview-questions-and-answers-article?source=frs_home
# ...

# %%
for article in sl_soup.find_all('h2'):
    print(article.string)
# Out:
# Program Preview: Post Graduate Program in Data Analytics
# Program Preview: Full Stack Java Developer- Job Guarantee Bootcamp
# Time Management: The Secret to Achieving Your Career Goals in 2022
# Skills to Feed Your Digital Marketing Career

# %%
for article in sl_soup.find_all('h4'):
    print(article.string)
# Out:
# Top 45 Data Structure Interview Questions in 2021
# Course Review: Use This Time to Pursue Your Dream Career
# Free eBook: Secret to Unlocking Tableau's Hidden Potential
# Is the Future of Retail in the Metaverse?
# Working With AWS MLOps Services
# Artificial Intelligence Career Guide: A Comprehensive Playbook to Becoming an AI Expert
# PRINCE2® Foundation & Practitioner Overview, Eligibility, and Exam Tips
# How to Stay Popular in Project Management Field?
# Free Mind-map: PMP Certification
# Top 3 Ethical Hacking Certifications
# What is COBIT?: Framework, Components, and Benefits
# Cybersecurity Trends: Where the Industry Is Heading in an Uncertain 2021
# What Is Kubernetes on AWS?
# How to Leverage AWS Analytic Tools for Your Business
# Getting Started With Multi-Cloud Architecture
# Top Kubernetes Tools You Can Use to Manage Containers
# Top 5 Features of Using Docker Swarm
# The Impact of DevOps in 2021
# Business Analyst Salary: How Much Does a Business Analyst Make?
# ...

# %%
url2='https://www.simplilearn.com/data-structure-interview-questions-and-answers-article?source=frs_home'
webpage2= urlopen(url2)
sl_article= BeautifulSoup(webpage2,'html.parser')
test=sl_article.find(class_="desig_author empty-text")

# %%
type(test)
# Out:
# bs4.element.Tag

# %%
test.find_all('p')
# Out:
# [<p>You may be wondering what questions you’ll face in your next data structure interview. Just remember that data structure interviewers aren’t trying to trick you and don’t expect perfection, but it’s their opportunity to ascertain your knowledge before they invest in your employment. Proper preparation is always advised.</p>,
#  <p>Data structures and algorithm questions are an important part of any programming job interview, especially one for <a href="https://www.simplilearn.com/tutorials/data-science-tutorial/what-is-data-science" rel="noopener" target="_blank" title="Data Science">Data Science</a> and Java-based role. Sound knowledge of <a href="https://www.simplilearn.com/data-structures-and-algorithms-article" rel="noopener" target="_blank" title="data structures and algorithms">data structures and algorithms</a> will help you stand apart from the herd. The following Data Structure interview questions will help you crack your next interview!</p>,
# ...

# %%
first_next_p=test.p
first_next_p
# Out:
# <p>You may be wondering what questions you’ll face in your next data structure interview. Just remember that data structure interviewers aren’t trying to trick you and don’t expect perfection, but it’s their opportunity to ascertain your knowledge before they invest in your employment. Proper preparation is always advised.</p>

# %%
first_next_sibling= first_next_p.next_sibling.next_sibling
first_next_sibling
# Out:
# <p>Data structures and algorithm questions are an important part of any programming job interview, especially one for <a href="https://www.simplilearn.com/tutorials/data-science-tutorial/what-is-data-science" rel="noopener" target="_blank" title="Data Science">Data Science</a> and Java-based role. Sound knowledge of <a href="https://www.simplilearn.com/data-structures-and-algorithms-article" rel="noopener" target="_blank" title="data structures and algorithms">data structures and algorithms</a> will help you stand apart from the herd. The following Data Structure interview questions will help you crack your next interview!</p>

# %%
prev=first_next_sibling.previous_sibling.previous_sibling
prev
# Out:
# <p>You may be wondering what questions you’ll face in your next data structure interview. Just remember that data structure interviewers aren’t trying to trick you and don’t expect perfection, but it’s their opportunity to ascertain your knowledge before they invest in your employment. Proper preparation is always advised.</p>
